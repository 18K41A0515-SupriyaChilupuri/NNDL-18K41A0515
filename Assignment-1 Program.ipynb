# %%
from sympy import *
x = Symbol('x')
y = diff(x**4+3*x**2+10,x)
print(f'first order derivative of given function is {y}')
#step 1 Initialization
x1 = 1.0  #variable x
itr = 20  #epoches
learning_rate = 0.1  #learning rate
for i in range(0,itr):
    #step 2 substitute x 
    x = symbols('x')
    df = y.subs(x, x1) 
    df = round(df,2)
    #step3 finding changes in  x 
    dx = (-1.0)*learning_rate*df
    #step4 updation of new variable 
    x1 = x1 + dx
    x1 = round(x1, 2)
    #step5 increment iterations 
    #step6 break loop if itr>eopches
#step7 print variable x1
print(x1)
print(f'minimum value obtained at x = {x1} for given function')
fn = x**4+3*x**2+10
print(f'value for (f(x)) at min value x = {x1} is {fn.subs(x,x1)}')
# Out:
# first order derivative of given function is 4*x**3 + 6*x
# 0.0
# minimum value obtained at x = 0.0 for given function
# value for (f(x)) at min value x = 0.0 is 10
